# %%
class person:
    # Constructor
    def __init__(self):
        print(" \t \t \t \n \n                             \t  Welcome to UIET COLLEGE OF ENGINEERING ")
        a=open("C:\\Users\\sony vaio\\Desktop\\full\\about.txt","r")
        b=a.read()
        print(b)
        self.name = str(input(" Enter Your Full Name: "))
        self.stuClass = str(input(" Enter Your Engineering Branch: "))
        self.age = float(input(" Enter Your Age: "))
        self.gender = str(input(" Enter your Gender M\F : "))
    
    # Method
    def display(self):
       
        print("\n\n Ypur Name is : ",self.name)
        print(" your Age is : ",self.age)
        print(" Your Gender is : ",self.gender)
        print("Your Engineering Branch is : ",self.stuClass)
        print("\n \n Student Personal Details are : ", self.name, "and your Age is",self.age,"and you are a ",self.gender,"student"," And Your Branch of Engineering is :",self.stuClass)
        print( " \n \n  \t \t Please enter your Details Below ! Basis on which we give find your RESULT  PAss/Fail \n  and if you are pass Enter details of Extra Ciricular Activities for Scholorship \n \n")      
        print( " ")


class marks():
    def __init__(self):
        self.first = int(input("Your Marks in first year 'out of 500'  : "))
        self.second = int(input("Your marks in Second year 'out of 500': "))
        self.third = int(input("Your Marks in Third year 'out of 500'  : "))
        self.fourth = int(input("Your Marks in fourth year 'out of 500': "))
        
     
     # Method
    def display(self):
        a=(self.first+self.second+self.third+self.fourth)
        print("Overall Marks of your B.tech  is :- ",a)
        
        #condition checking
        
        if a>=500:
            print(" \n \t \t \t \t  CONGRATS ! You are passed :) your Overall score is : ", a)
        else:
            print(" \n \t \t \t \t                SORRY YOU ARE FAIL ! TRY NEXT YEAR  :(  " )
            stu1 = student()
            stu1.result()
            a=bestmarks()
            a.display()
            
            
        

#
class student(person, marks):  #inheritance
    def __init__(self):
        # Call constructor of super class 'person'
        person.__init__(self)
        # Call constructor of super class 'marks'
        marks.__init__(self)
        
    def result(self):
        # Call method of class 'person'
        person.display(self)
        # Call method of class 'marks'
        marks.display(self)           

        

class bestmarks(student):
    def __init__(self):
        student. __init__(self)
        self.extra = input(" Marks in Extra Ciricular Activites: ")
        print("Enter the marks of the respective subjects")
        self.a = int(input("sports: "))
        self.m = int(input("computer: "))
        self.b = int(input("music: "))
         
    def display(self):
        print("overall ",self.name,self.age,self.gender,self.stuClass,self.extra,self.first,self.second,self.third,self.fourth, self.a+ self.m + self.b)
        print(" \t \t \t \n \n \t \t \t \t \t  \t    CONGRATS ! \n \t \t \t \n \n \t \t \t \t \t Welcome Toppers For next Level ! ")
        print(" Your marks in sports from 500: ") 
        print(" your marks in computer from 500: ")
        print(  " your marks in music from 500: " )
        yy=(self.a+self.m+self.b)
        zz=yy/1500
        aa=zz*100
        print(" Your overall Topper RESULT from strting to End is :-", self.a+self.m+self.b ,"From 300 and percantage is :-",aa )

        
#making object
        
stu1 = student()
stu1.result()
a=bestmarks()
a.display()
